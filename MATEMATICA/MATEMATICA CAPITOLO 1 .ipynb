# %% [markdown]
# f(x)=$\sqrt{\frac{x^2-5x+6}{x^2-1}}$

# %% [markdown]
# **PRIMA DISEQUAZIONE**
#
# $x<2\lor{}x>3$

# %% [markdown]
# **SECONDA DISEQUAZIONE**
#
# $x<1\lor{x}>1$

# %% [markdown]
# |$x$|$-\infty{}$|$1$|$2$|$3$|$+\infty{}$|
# |:-:|:-:|:-:|:-:|:-:|:-:|
# |N|$+$|$+$|$-$|$-$|$+$|
# |D|

# %% [markdown]
# **N52**
#
# $f(x)=\frac{3+x}{(3-x)*(3+x)*(x^2+2x+3)}$

# %% [markdown]
# **N53**
#
# $f(x)=\sqrt{\frac{x-3}{3x-5}}$

# %% [markdown]
# **NUMERATORE**
#
# $x\geq{}3$

# %% [markdown]
# **DENOMINATORE**
#
# $x>\frac{5}{3}$

# %% [markdown]
# **N54**
#
# f(x)=$\sqrt{3x^2-13x+4}$

# %% [markdown]
# $\frac{1}{3}\leq{x}\leq{4}$

# %% [markdown]
# **N142**
#
# $f(x)=\frac{1}{2cosx-1}$

# %% [markdown]
# **N146**
#
# $f(x)=\sqrt{sinx}$

# %% [markdown]
# **N278**

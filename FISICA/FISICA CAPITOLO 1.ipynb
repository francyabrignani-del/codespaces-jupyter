# %%
from IPython.display import Math, display

#FENOMENI MAGNETICI
#I materiali che possono magnetizzarsi cioè resi capace di attrarre il ferro
#chiamati FERROMAGNETICI
#due poli nord e sud

#POLO NORD-----> SUD MAGNETICO
#POLO SUD------>. NORD MAGNETICO

#lo spazio oltre ad avere campo elettrico ha campo magnetico indicato con 
display(Math(r"B(v)"))
#il campo magneticvo si avvolge attorno il campo elettrico
#se le cariche elettriche sono in movimento si crea il campo magnetico legato chiamato elettromagnetismo  

#ESPERIMENTO DI OERSTED 1820
# una correnta elettrica esercita una forza, più precisamente un momento di forza che fa ruotare il magnete  
#quindi questo esperimento afferma che la corrente elettrica crea un campo magnetico

#ESPERIMENTO DI FARADAY
#un filo percorso da corrente , posto in un campo magnetico, subisce una forza

print("MAGNETISMO",flush=True)
print("===================================================",flush=True)
domanda1=input("come si chiamano i materiali capaci di attrarre ferro? ")
if domanda1=="ferromagnetici":
    print("RISPOSTA ESATTA",flush=True)
else:
    print("RISPOSTA ERRATA",flush=True)
print("======================================================",flush=True)

print("SECONDA DOMANDA",flush=True)
domanda2=input("Vero o falso: le cariche elettriche devono stare ferme per generare un campo magnetico ",)
if domanda2=="falso":
    print("RISPOSTA ESATTA",flush=True)
else:
    print("RISPOSTA ERRATA",flush=True)
print("ESPERIMENTO DI OERSTED 1820",flush=True)
print("in cosa consisteva questo esperimento?",flush=True)
print("1 in far passare cariche elettriche parallelamente, 2. di far ruotare un magnete con un altro magnerte, 3. di far passare una corrente elettrica vicino un magnete",flush=True)
domanda3=int(input())
if domanda3==3:
    print("RISPOSTA ESATTA",flush=True)
else:
    print("RISPOSTA ERRATA",flush=True)


print("====================================================",flush=True)
print("ESPERIMENTO DI FARADAY",flush=True)
print("DOMANDA 4",flush=True)
print("in cosa consisteva questo esperimento?",flush=True)
print("1. di far girare un magnete con la corrente elettrica,2. di far attraversare la corrente elttrica da un magnete, 3. di far passare due fili in modo parallelo contenenti corrente elettrica",flush=True)
domanda4=int(input(""))
if domanda4==3:
    print("RISPOSTA ESATTA",flush=True)
else:
    print("RISPOSTA ERRATA",flush=True)
print("test finito")
for i in range(1,11):
    print(":>")
# Out:
# $\displaystyle B(v)$
# MAGNETISMO
# ...
# RISPOSTA ESATTA
# ...
# SECONDA DOMANDA
# RISPOSTA ESATTA
# ESPERIMENTO DI OERSTED 1820
# in cosa consisteva questo esperimento?
# 1 in far passare cariche elettriche parallelamente, 2. di far ruotare un magnete con un altro magnerte, 3. di far passare una corrente elettrica vicino un magnete
# RISPOSTA ESATTA
# ...
# ESPERIMENTO DI FARADAY
# DOMANDA 4
# in cosa consisteva questo esperimento?
# 1. di far girare un magnete con la corrente elettrica,2. di far attraversare la corrente elttrica da un magnete, 3. di far passare due fili in modo parallelo contenenti corrente elettrica
# RISPOSTA ESATTA
# test finito
# :>
# :>
# :>
# :>
# :>
# :>
# :>
# :>
# :>
# :>

# %%
from IPython.display import Math, display

#FENOMENI MAGNETICI
#I materiali che possono magnetizzarsi cioè resi capace di attrarre il ferro
#chiamati FERROMAGNETICI
#due poli nord e sud

#POLO NORD-----> SUD MAGNETICO
#POLO SUD------>. NORD MAGNETICO

#lo spazio oltre ad avere campo elettrico ha campo magnetico indicato con 
display(Math(r"B(v)"))
#il campo magneticvo si avvolge attorno il campo elettrico
#se le cariche elettriche sono in movimento si crea il campo magnetico legato chiamato elettromagnetismo  

#ESPERIMENTO DI OERSTED 1820
# una correnta elettrica esercita una forza, più precisamente un momento di forza che fa ruotare il magnete  
#quindi questo esperimento afferma che la corrente elettrica crea un campo magnetico

#ESPERIMENTO DI FARADAY
#un filo percorso da corrente , posto in un campo magnetico, subisce una forza
# Out:
# $\displaystyle B(v)$

# %%
from IPython.display import Math, display

#AGE OF CONFLICT
#362-363 page
#first world war and the second world war
#1914-1918
#1901-1949

#AFTER THE DEAD OF THE QUEEN VICTORIA EDWARD BECAME THE NEW KING
#at the age of 59
#he spend his life traveling in britain, north america and india 
#he became a popolar publc figure
#HIS REIGN 1901-1909
#AFTER 5 YEARS THERE WERE THE ELECTIONS
#1.where people can work of max 8 hours
#2.pension system
#3.insurance national system

#GEORGE V
#in 1910 on the death of his fther he become the king


#NEW MOVEMENT FOUND IN MANCHESTER

#THE SUDDEN END OF AN AGE OF OPMIMISM
#BELLE EPOQUE
#indstrial & economy growth 

#THE GREAT WAR BREAKS OUT
#the immediate cause of ww1 was the assassination of the austrian archduke Franz Ferdinand in june 1914.
#george V declared war on Germany on 28 july 1914 and the italy entered in 24 may 1915
#two alliances the triple alliance and the triple entente
#the italy was in the triple entente and before with the triple alliance
#the united states joined thw war in april 1917 and germany defeated one year later
#after the armisticen in 1919 there was the treaty of versailles signed in paris on 28 june living the empires destroyed,like econmy and politic


#THE IRISH QUESTION
#after the first decade of 20th 
#irland was under control of irland 
#but irish people asked for indipendence
#with ww1 the question left
#in 1922 the state of irland but not the all island
#the nord part of the island was under control of england

print("=====================",flush=True)
print("THE AGE OF CONFLICT",flush=True)
print("=====================",flush=True)
print("Why it is called the age of conflict?",flush=True)
print("=====================================",flush=True)
print("FIRST PART",flush=True)
print("=====================================",flush=True)
print("1.for many wars in America, 2. for many wars in general, 3. for ww1 and ww2",flush=True)
risposta1=int(input())
if risposta1==3:
    print("RISPOSTA ESATTA",flush=True)
else:
    print("RISPOSTA ERRATA")   
risposta2=input("for how much years there was the ww1? ")
if risposta2=="1914-1918":
    print("RISPOSTA ESATTA",flush=True)
else:
    print("RISPOSTA ERRATA")
print("======================================================================")
print("PART 2")
risposta3=input("what king succeded after the death of the queen victoria? ")
if risposta3=="edward":
    print("RISPOSTA CORRETTA",flush=True)
else:
    print("RISPOSTA ERRATA")
risposta4=input("where did he traveled? ")
if risposta4=="britain north america india":
    print("RISPOSTA CORRETTA",flush=True)
else:
    print("RISPOSTA ERRATA")
risposta5=input("How much time alive stayed his reign? ")
if risposta5=="1901-1909":
    print("RISPOSTA CORRETTA",flush=True)
else:
    print("RISPOSTA ERRATA")
print("WHAT REFORMS DID HE DO?",flush=True)
print("1.equality and fratellance",flush=True)
print("2.pension system, max hours of work",flush=True)
print("3.less taxes for all",flush=True)
risposta6=int(input(""))
if risposta6==2:
    print("RISPOSTA CORRETTA",flush=True)
else:
    print("RISPOSTA ESATTA")

risposta7=input("what king become the king after edward? ")
if risposta7==("george v"):
    print("RISPOSTA ESATTA")
else:
    print("RISPOSTA ERRATA")
# Out:
# ...
# THE AGE OF CONFLICT
# ...
# Why it is called the age of conflict?
# ...
# FIRST PART
# ...
# 1.for many wars in America, 2. for many wars in general, 3. for ww1 and ww2
# RISPOSTA ESATTA
# RISPOSTA ESATTA
# ...
# PART 2
# RISPOSTA CORRETTA
# RISPOSTA ERRATA
# RISPOSTA CORRETTA
# WHAT REFORMS DID HE DO?
# 1.equality and fratellance
# 2.pension system, max hours of work
# 3.less taxes for all
# RISPOSTA CORRETTA
# RISPOSTA ESATTA
